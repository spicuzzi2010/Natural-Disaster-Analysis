# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
disasterCostData = "MissionAssignments.csv"
cost_df = pd.read_csv(disasterCostData)
cost_df.head()
# Out:
#                maId  amendmentNumber          city stateorTribe    zip  \
# 0  3345EMWVCOENAD03                3           NaN          NaN    NaN
# 1  3345EMWVCOELRD02                2  Philadelphia           PA  19143
# 2  3345EMWVCOELRD02                0  Philadelphia           PA  19143
# 3  3345EMWVCOENAD01                1   Washington            DC  20472
# 4     3345EMWVDOT01                0    Washington           DC  20472
#
#    disasterNumber declarationType   agency  \
# 0            3345              EM  COE-NAD
# 1            3345              EM  COE-LRD
# 2            3345              EM  COE-LRD
# 3            3345              EM  COE-NAD
# 4            3345              EM      DOT
#
#                                  assistanceRequested  \
# 0  7/25/2012 Amendment 2 - Reduce by $1M and  awa...
# 1  212/2013, Amendment #2: dobligate $40,061.29 a...
# 2  USACE - Activate the U.S. Army Corps of Engine...
# 3  Amend to deobligated and close this MA in the ...
# 4  Activate Department of Transportation (DOT) to...
#
#                                      statementOfWork  ...  \
# 0  Implement the Advanced Contracting Initiative,...  ...
# 1  Activate the USACE to perform functions of Eme...  ...
# 2  Activate the USACE to perform functions of Eme...  ...
# 3  Post-Declaration activation for appropriate US...  ...
# 4  Post Declaration activation for appropriate DO...  ...
#
#               dateRequested             dateObligated stateCostSharePct  \
# 0  2012-07-25T20:07:37.000Z  2012-07-25T20:02:47.000Z               0.0
# 1  2013-02-13T15:24:02.000Z  2013-02-13T14:58:54.000Z               0.0
# 2  2012-07-02T12:13:42.000Z  2012-07-01T22:10:10.000Z               0.0
# 3  2012-08-21T15:14:30.000Z  2012-08-21T14:12:04.000Z               0.0
# 4  2012-07-01T15:50:22.000Z  2012-07-01T00:41:08.000Z               0.0
#
#   federalCostSharePct  stateCostShareAmt  federalCostShareAmt  \
# 0                 0.0                NaN                  NaN
# 1                 0.0                NaN                  NaN
# 2                 1.0                0.0              46500.0
# 3                 0.0                NaN                  NaN
# 4                 1.0                0.0               2000.0
#
#    requestedAmount  obligationAmount   projectedCompletionDate  \
# 0      -1000000.00       -1000000.00  2012-07-31T00:00:00.000Z
# 1        -40061.29         -40061.29  2012-07-13T00:00:00.000Z
# 2         46500.00          46500.00  2012-07-07T00:00:00.000Z
# 3         -5672.82          -5672.82  2012-07-07T00:00:00.000Z
# 4          2000.00           2000.00  2012-07-07T00:00:00.000Z
#
#                          id
# 0  6117f089f3de2d084ba301b6
# 1  6117f089f3de2d084ba301ae
# 2  6117f089f3de2d084ba301ac
# 3  6117f089f3de2d084ba301b0
# 4  6117f089f3de2d084ba301c4
#
# [5 rows x 22 columns]

# %%
disasterGroup = cost_df.groupby(["disasterNumber"]).sum()
disasterGroup.head()
# Out:
#                 amendmentNumber  stateCostSharePct  federalCostSharePct  \
# disasterNumber
# 3345                         77               0.25                 31.0
# 3346                         18               0.75                  7.5
# 3347                        210               0.00                 59.0
# 3348                         22               0.00                 11.0
# 3349                          6               0.00                  4.0
#
#                 stateCostShareAmt  federalCostShareAmt  requestedAmount  \
# disasterNumber
# 3345                          0.0           3481939.92        904490.14
# 3346                     225000.0            906000.00        842464.67
# 3347                          0.0           8865692.86       1409793.92
# 3348                          0.0           2155000.00        253189.73
# 3349                          0.0            800000.00             0.00
#
#                 obligationAmount
# disasterNumber
# 3345                   904490.14
# 3346                   842464.67
# 3347                  1409793.92
# 3348                   253189.73
# 3349                        0.00

# %%
disasterGroup = disasterGroup[["obligationAmount"]]
disasterGroup.reset_index(inplace=True)
disasterGroup.head()
# Out:
#    disasterNumber  obligationAmount
# 0            3345         904490.14
# 1            3346         842464.67
# 2            3347        1409793.92
# 3            3348         253189.73
# 4            3349              0.00

# %%
disaster_summaries = 'DisasterDeclarationsSummaries.csv'
disaster_summaries_df = pd.read_csv(disaster_summaries)
disaster_summaries_df.head()
# Out:
#   femaDeclarationString  disasterNumber state     state.1 declarationType  \
# 0            DR-4607-MI            4607    MI    Michigan              DR
# 1            DR-4607-MI            4607    MI    Michigan              DR
# 2            FM-5398-WA            5398    WA  Washington              FM
# 3            FM-5397-WA            5397    WA  Washington              FM
# 4            FM-5396-OR            5396    OR      Oregon              FM
#
#             declarationDate  fyDeclared   incidentType  \
# 0  2021-07-15T10:41:00.000Z        2021  Severe Storms
# 1  2021-07-15T10:41:00.000Z        2021  Severe Storms
# 2  2021-07-14T18:36:00.000Z        2021           Fire
# 3  2021-07-13T21:27:00.000Z        2021           Fire
# 4  2021-07-10T20:22:00.000Z        2021           Fire
#
#                            declarationTitle  ihProgramDeclared  ...  \
# 0  SEVERE STORMS,  FLOODING,  AND TORNADOES                  1  ...
# 1  SEVERE STORMS,  FLOODING,  AND TORNADOES                  1  ...
# 2                            RED APPLE FIRE                  0  ...
# 3                        CHUWEAH CREEK FIRE                  0  ...
# 4                              BOOTLEG FIRE                  0  ...
#
#    placeCode               designatedArea  declarationRequestNumber  \
# 0      99163                 Wayne County                     21051
# 1      99161             Washtenaw County                     21051
# 2          0                    Statewide                     21054
# 3      14240  Colville Indian Reservation                     21052
# 4      99035               Klamath County                     21053
#
#                                        hash               lastRefresh  \
# 0  6862d74686de9eaea31be8c0d33a0051867f674c  2021-07-17T02:42:14.846Z
# 1  c9f45069cae6640e009712d996cd8481e7b081f0  2021-07-17T02:42:14.846Z
# 2  0a1f400f649de3ab95d21912ded0f302c7473449  2021-07-17T02:42:15.243Z
# 3  5f811f571c49e7b0ac2763d00fa633afa360b4e7  2021-07-17T02:42:15.242Z
# 4  d5f2cd7a57557a2f7e245570c783bc293a14b530  2021-07-17T02:42:15.241Z
#
#                          id                              countyState  \
# 0  60f243865d037ccb7d217dbd                   Wayne County, Michigan
# 1  60f243865d037ccb7d217dba               Washtenaw County, Michigan
# 2  60f243875d037ccb7d2181eb                               Washington
# 3  60f243875d037ccb7d2181e7  Colville Indian Reservation, Washington
# 4  60f243875d037ccb7d2181e5                   Klamath County, Oregon
#
#    Unnamed: 25  Unnamed: 26 Unnamed: 27
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN
# 2          NaN          NaN         NaN
# 3          NaN          NaN         NaN
# 4          NaN          NaN         NaN
#
# [5 rows x 28 columns]

# %%
new_disaster_summaries_df = disaster_summaries_df[['disasterNumber', 'state','incidentType', 'declarationTitle', 'incidentBeginDate']]
new_disaster_summaries_df.head()
# Out:
#    disasterNumber state   incidentType  \
# 0            4607    MI  Severe Storms
# 1            4607    MI  Severe Storms
# 2            5398    WA           Fire
# 3            5397    WA           Fire
# 4            5396    OR           Fire
#
#                            declarationTitle         incidentBeginDate
# 0  SEVERE STORMS,  FLOODING,  AND TORNADOES  2021-06-25T00:00:00.000Z
# 1  SEVERE STORMS,  FLOODING,  AND TORNADOES  2021-06-25T00:00:00.000Z
# 2                            RED APPLE FIRE  2021-07-13T03:01:00.000Z
# 3                        CHUWEAH CREEK FIRE  2021-07-12T03:01:00.000Z
# 4                              BOOTLEG FIRE  2021-07-10T03:01:00.000Z

# %%
new_disaster_summaries_df.drop_duplicates(subset=['disasterNumber'], keep = 'first', inplace = True)
new_disaster_summaries_df.head()
# Out:
# <ipython-input-7-2a22d5e5bb19>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_disaster_summaries_df.drop_duplicates(subset=['disasterNumber'], keep = 'first', inplace = True)
#    disasterNumber state   incidentType  \
# 0            4607    MI  Severe Storms
# 2            5398    WA           Fire
# 3            5397    WA           Fire
# 4            5396    OR           Fire
# 5            5395    WA           Fire
#
#                            declarationTitle         incidentBeginDate
# 0  SEVERE STORMS,  FLOODING,  AND TORNADOES  2021-06-25T00:00:00.000Z
# 2                            RED APPLE FIRE  2021-07-13T03:01:00.000Z
# 3                        CHUWEAH CREEK FIRE  2021-07-12T03:01:00.000Z
# 4                              BOOTLEG FIRE  2021-07-10T03:01:00.000Z
# 5                               ANDRUS FIRE  2021-07-05T03:01:00.000Z

# %%
#disaster_cost_df = disasterGroup.join(new_disaster_summaries_df, on='disasterNumber')
disaster_cost_df = pd.merge(disasterGroup, new_disaster_summaries_df, on='disasterNumber')
disaster_cost_df
# Out:
#      disasterNumber  obligationAmount state   incidentType  \
# 0              3345         904490.14    WV  Severe Storms
# 1              3346         842464.67    OH  Severe Storms
# 2              3347        1409793.92    LA      Hurricane
# 3              3348         253189.73    MS      Hurricane
# 4              3349              0.00    MD      Hurricane
# ..              ...               ...   ...            ...
# 414            4589          78140.23    ID  Severe Storms
# 415            4593           2500.00    WA  Severe Storms
# 416            4601          10000.00    TN        Tornado
# 417            4606          10000.00    LA          Flood
# 418            4607         161200.00    MI  Severe Storms
#
#                                       declarationTitle  \
# 0                                        SEVERE STORMS
# 1                                        SEVERE STORMS
# 2                                 TROPICAL STORM ISAAC
# 3                                 TROPICAL STORM ISAAC
# 4                                      HURRICANE SANDY
# ..                                                 ...
# 414                                STRAIGHT-LINE WINDS
# 415  SEVERE WINTER STORM,  STRAIGHT-LINE WINDS,  FL...
# 416           SEVERE STORMS,  TORNADOES,  AND FLOODING
# 417           SEVERE STORMS,  TORNADOES,  AND FLOODING
# 418           SEVERE STORMS,  FLOODING,  AND TORNADOES
#
#             incidentBeginDate
# 0    2012-06-29T22:30:00.000Z
# 1    2012-06-29T22:00:00.000Z
# 2    2012-08-26T00:00:00.000Z
# 3    2012-08-26T00:00:00.000Z
# 4    2012-10-26T15:36:00.000Z
# ..                        ...
# 414  2021-01-13T00:00:00.000Z
# 415  2020-12-29T00:00:00.000Z
# 416  2021-03-25T00:01:00.000Z
# 417  2021-05-17T08:00:00.000Z
# 418  2021-06-25T00:00:00.000Z
#
# [419 rows x 6 columns]

# %%
X = disaster_cost_df["disasterNumber"].values.reshape(-1, 1)
y = disaster_cost_df["obligationAmount"].values.reshape(-1, 1)

print('shape: ', X.shape, y.shape)
# Out:
# shape:  (419, 1) (419, 1)

# %%
plt.scatter(X, y)
plt.xlabel("disaster")
plt.ylabel("cost")
# Out:
# Text(0, 0.5, 'cost')
