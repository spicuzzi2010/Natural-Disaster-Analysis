# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
disaster_data = "static/data/disasterData.csv"
disaster_data_df = pd.read_csv(disaster_data)
disaster_data_df.head()
# Out:
#    Unnamed: 0 femaDeclarationString  disasterNumber   stateName state  \
# 0           0            DR-1943-NY            1943    New York    NY
# 1           1            DR-1943-NY            1943    New York    NY
# 2           2            DR-1943-NY            1943    New York    NY
# 3           3            DR-1952-CA            1952  California    CA
# 4           4            DR-1952-CA            1952  California    CA
#
#   declarationType           declarationDate  fyDeclared incidentType  \
# 0              DR  2010-10-14T16:50:00.000Z        2011      Tornado
# 1              DR  2010-10-14T16:50:00.000Z        2011      Tornado
# 2              DR  2010-10-14T16:50:00.000Z        2011      Tornado
# 3              DR  2011-01-26T15:00:00.000Z        2011        Flood
# 4              DR  2011-01-26T15:00:00.000Z        2011        Flood
#
#                                     declarationTitle  ...  fipsCountyCode  \
# ...

# %%
disaster_data_df_cleaned = disaster_data_df[['designatedArea','stateName','lat','lon','fyDeclared','declarationDate','incidentType','declarationTitle',]].copy()

# %%
disaster_data_df_cleaned.rename(columns={'designatedArea': 'county', 'stateName': 'state','fyDeclared': 'year','declarationDate': 'date',})
# Out:
#                   county       state        lat         lon  year  \
# 0           Kings County    New York  40.645310  -73.955023  2011
# 1          Queens County    New York  40.652493  -73.791421  2011
# 2        Richmond County    New York  40.564209  -74.125305  2011
# 3            Inyo County  California  36.559533 -117.407471  2011
# 4            Kern County  California  35.314570 -118.753822  2011
# ..                   ...         ...        ...         ...   ...
# 961    Rensselaer County    New York  42.709139  -73.510773  2013
# 962      Richmond County    New York  40.564209  -74.125305  2013
# 963      Rockland County    New York  41.151932  -74.035727  2013
# 964  St. Lawrence County    New York  44.497359  -75.065704  2013
# 965      Saratoga County    New York  43.083323  -73.871216  2013
#
#                          date incidentType  \
# 0    2010-10-14T16:50:00.000Z      Tornado
# 1    2010-10-14T16:50:00.000Z      Tornado
# ...
