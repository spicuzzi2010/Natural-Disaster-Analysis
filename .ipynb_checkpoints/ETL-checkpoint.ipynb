# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
tornado_file = "static/data/Historical_Tornado_Tracks.csv"
tornado_df = pd.read_csv(tornado_file)
tornado_df.head()
# Out:
#     FID   OM    YR  MO  DY        DATE      TIME  TZ  ST  STF  ...  FAT  \
# 0  2001  141  2002   6   5  2002-06-05  16:45:00   3  FL   12  ...    0
# 1  2002  142  2002   6   8  2002-06-08  13:40:00   3  FL   12  ...    0
# 2  2003  145  2002   6  17  2002-06-17  16:40:00   3  FL   12  ...    0
# 3  2004  187  2002   7  11  2002-07-11  12:30:00   3  FL   12  ...    0
# 4  2005  188  2002   7  12  2002-07-12  06:30:00   3  FL   12  ...    0
#
#     LOSS  CLOSS   SLAT   SLON   ELAT   ELON  LEN  WID  Shape_Leng
# 0  0.000    0.0  28.08 -82.78  28.08 -82.78  0.1   20    0.000000
# 1  0.500    0.0  27.73 -82.73  27.72 -82.75  1.0   40    0.022361
# 2  0.000    0.0  27.48 -82.72  27.48 -82.72  0.1   20    0.000000
# 3  0.020    0.0  27.77 -82.77  27.77 -82.77  0.5   40    0.000000
# 4  0.001    0.0  27.92 -82.80  27.92 -82.80  0.5   40    0.000000
#
# [5 rows x 23 columns]

# %%
earthquake_file = "static/data/earthquakes_2011-2013.csv"
earthquake_df = pd.read_csv(earthquake_file)
earthquake_df.head()
# Out:
#                        time  latitude  longitude  depth  mag magType    nst  \
# 0  2012-04-12T07:15:48.500Z   28.6960  -113.1040  13.00  7.0     mww  474.0
# 1  2013-10-19T17:54:54.700Z   26.0913  -110.3209   9.45  6.6     mww    NaN
# 2  2012-12-14T10:36:01.590Z   31.0950  -119.6600  13.00  6.3     mww  760.0
# 3  2012-09-25T23:45:24.940Z   24.6660  -110.1730  10.00  6.3     mww  659.0
# 4  2011-07-26T17:44:20.380Z   25.1010  -109.5250  12.00  6.0     mww  379.0
#
#     gap  dmin   rms  ...                   updated  \
# 0  95.9   NaN  1.18  ...  2020-09-21T18:04:24.284Z
# 1  44.0  1.98  1.10  ...  2020-07-10T18:20:12.984Z
# 2  20.9   NaN  1.29  ...  2020-05-06T09:28:04.095Z
# 3  25.7   NaN  1.00  ...  2020-09-21T18:24:36.158Z
# 4  81.3   NaN  1.19  ...  2015-06-30T16:59:03.875Z
#
#                               place        type horizontalError depthError  \
# 0     69 km ENE of San Luis, Mexico  earthquake             NaN        NaN
# 1     98 km SW of Etchoropo, Mexico  earthquake             NaN        3.0
# 2  279 km SSW of Avalon, California  earthquake             NaN        NaN
# 3       59 km NNE of La Paz, Mexico  earthquake             NaN        NaN
# 4   73 km SW of Topolobampo, Mexico  earthquake             NaN        NaN
#
#    magError  magNst    status  locationSource magSource
# 0       NaN     NaN  reviewed              us        us
# 1       NaN     NaN  reviewed              us        us
# 2       NaN     NaN  reviewed              us        us
# 3       NaN     NaN  reviewed              us        us
# 4       NaN     NaN  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
# Create a filtered dataframe from specific columns
earthquake_cols = ["time", "latitude", "longitude", "mag"]
earthquake_transformed= earthquake_df[earthquake_cols].copy()

# Rename the column headers
earthquake_transformed = earthquake_transformed.rename(columns={"time": "date",
                                                          "latitude": "lat",
                                                          "longitude": "lon"})

# Clean the data by dropping duplicates and setting the index
#earthquake_transformed.drop_duplicates("id", inplace=True)
#earthquake_transformed.set_index("id", inplace=True)

earthquake_transformed.head()
# Out:
#                        date      lat       lon  mag
# 0  2012-04-12T07:15:48.500Z  28.6960 -113.1040  7.0
# 1  2013-10-19T17:54:54.700Z  26.0913 -110.3209  6.6
# 2  2012-12-14T10:36:01.590Z  31.0950 -119.6600  6.3
# 3  2012-09-25T23:45:24.940Z  24.6660 -110.1730  6.3
# 4  2011-07-26T17:44:20.380Z  25.1010 -109.5250  6.0
